# %% [markdown]
# # Student Details
#
# - **Name:** Vinit Sindhal
# - **Enroll no.:** 2503051240126
# - **Roll no.:** 31
# - **Division/Batch:** 2B3/2nd
#
# Link : https://colab.research.google.com/drive/1Aff8UXX1p3otQFVnhKUZ40nVIJBJYhp2#scrollTo=OO1T_LxtRB0Z

# %% [markdown]
# #Practical 10
# Build and Train a Simple Deep Learning Model
#
# Aim:
# To build a simple deep neural network (DNN) for classification and train
# it on a dataset.

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris

# %%
#Load Iris dataset
data = load_iris()
X = data.data
       # Features
y = data.target
     # Labels
# One-hot encode target labels
y = to_categorical(y, num_classes=3)
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = Sequential()
model.add(Dense(16, input_dim=4, activation='relu'))  # Input layer + hiddenlayer
model.add(Dense(12, activation='relu'))               # Hidden layer
model.add(Dense(3, activation='softmax'))             # Output layer for 3 classes
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history=model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=5,
    validation_split=0.2
)
# Out:
# Epoch 1/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - accuracy: 0.3571 - loss: 1.0025 - val_accuracy: 0.3810 - val_loss: 0.9301
# Epoch 2/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4643 - loss: 0.9489 - val_accuracy: 0.6667 - val_loss: 0.8979
# Epoch 3/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5714 - loss: 0.9094 - val_accuracy: 0.6190 - val_loss: 0.8741
# Epoch 4/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6667 - loss: 0.8797 - val_accuracy: 0.7143 - val_loss: 0.8584
# Epoch 5/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6905 - loss: 0.8481 - val_accuracy: 0.6667 - val_loss: 0.8380
# Epoch 6/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6905 - loss: 0.8100 - val_accuracy: 0.6667 - val_loss: 0.8111
# Epoch 7/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6786 - loss: 0.7808 - val_accuracy: 0.5714 - val_loss: 0.7874
# Epoch 8/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6310 - loss: 0.7515 - val_accuracy: 0.6667 - val_loss: 0.7532
# Epoch 9/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7143 - loss: 0.7214 - val_accuracy: 0.6667 - val_loss: 0.7342
# Epoch 10/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7262 - loss: 0.6901 - val_accuracy: 0.7143 - val_loss: 0.7126
# Epoch 11/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7143 - loss: 0.6651 - val_accuracy: 0.7619 - val_loss: 0.6892
# Epoch 12/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7500 - loss: 0.6378 - val_accuracy: 0.7143 - val_loss: 0.6614
# Epoch 13/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7500 - loss: 0.6143 - val_accuracy: 0.8095 - val_loss: 0.6483
# Epoch 14/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8095 - loss: 0.5918 - val_accuracy: 0.8571 - val_loss: 0.6256
# Epoch 15/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8452 - loss: 0.5745 - val_accuracy: 0.9524 - val_loss: 0.6113
# Epoch 16/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7976 - loss: 0.5544 - val_accuracy: 0.7619 - val_loss: 0.5897
# Epoch 17/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7143 - loss: 0.5391 - val_accuracy: 0.7143 - val_loss: 0.5733
# Epoch 18/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8810 - loss: 0.5256 - val_accuracy: 0.9524 - val_loss: 0.5682
# Epoch 19/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9048 - loss: 0.5147 - val_accuracy: 0.9048 - val_loss: 0.5501
# Epoch 20/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9286 - loss: 0.5046 - val_accuracy: 0.9524 - val_loss: 0.5514
# Epoch 21/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9405 - loss: 0.4906 - val_accuracy: 1.0000 - val_loss: 0.5335
# Epoch 22/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7857 - loss: 0.4810 - val_accuracy: 0.8095 - val_loss: 0.5145
# Epoch 23/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8929 - loss: 0.4728 - val_accuracy: 0.9524 - val_loss: 0.5200
# Epoch 24/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9405 - loss: 0.4602 - val_accuracy: 1.0000 - val_loss: 0.5039
# Epoch 25/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8810 - loss: 0.4540 - val_accuracy: 1.0000 - val_loss: 0.4930
# Epoch 26/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9524 - loss: 0.4461 - val_accuracy: 1.0000 - val_loss: 0.4919
# Epoch 27/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9405 - loss: 0.4372 - val_accuracy: 1.0000 - val_loss: 0.4803
# Epoch 28/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9643 - loss: 0.4284 - val_accuracy: 1.0000 - val_loss: 0.4739
# Epoch 29/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8571 - loss: 0.4290 - val_accuracy: 1.0000 - val_loss: 0.4606
# Epoch 30/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9286 - loss: 0.4205 - val_accuracy: 0.9524 - val_loss: 0.4778
# Epoch 31/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9048 - loss: 0.4150 - val_accuracy: 0.9524 - val_loss: 0.4355
# Epoch 32/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9286 - loss: 0.4045 - val_accuracy: 0.9524 - val_loss: 0.4507
# Epoch 33/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9643 - loss: 0.3886 - val_accuracy: 1.0000 - val_loss: 0.4217
# Epoch 34/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9524 - loss: 0.3847 - val_accuracy: 0.9524 - val_loss: 0.4348
# Epoch 35/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9405 - loss: 0.3771 - val_accuracy: 1.0000 - val_loss: 0.4074
# Epoch 36/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9405 - loss: 0.3651 - val_accuracy: 0.9524 - val_loss: 0.4169
# Epoch 37/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9524 - loss: 0.3591 - val_accuracy: 1.0000 - val_loss: 0.3995
# Epoch 38/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9643 - loss: 0.3542 - val_accuracy: 1.0000 - val_loss: 0.3995
# Epoch 39/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9524 - loss: 0.3470 - val_accuracy: 1.0000 - val_loss: 0.3844
# Epoch 40/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9643 - loss: 0.3393 - val_accuracy: 1.0000 - val_loss: 0.3776
# Epoch 41/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9405 - loss: 0.3396 - val_accuracy: 1.0000 - val_loss: 0.3711
# Epoch 42/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9762 - loss: 0.3305 - val_accuracy: 1.0000 - val_loss: 0.3689
# Epoch 43/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9524 - loss: 0.3293 - val_accuracy: 1.0000 - val_loss: 0.3533
# Epoch 44/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9524 - loss: 0.3169 - val_accuracy: 1.0000 - val_loss: 0.3423
# Epoch 45/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9643 - loss: 0.3116 - val_accuracy: 1.0000 - val_loss: 0.3471
# Epoch 46/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9643 - loss: 0.3026 - val_accuracy: 1.0000 - val_loss: 0.3301
# Epoch 47/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9643 - loss: 0.3004 - val_accuracy: 1.0000 - val_loss: 0.3334
# Epoch 48/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9524 - loss: 0.2926 - val_accuracy: 1.0000 - val_loss: 0.3156
# Epoch 49/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9643 - loss: 0.2861 - val_accuracy: 1.0000 - val_loss: 0.3142
# Epoch 50/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9643 - loss: 0.2904 - val_accuracy: 1.0000 - val_loss: 0.3055
